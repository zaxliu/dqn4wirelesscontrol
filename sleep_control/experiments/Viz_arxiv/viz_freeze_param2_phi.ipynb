# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'step']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# # Phi=1

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-4_2340B.log",  # 1
    "message_2016-6-5_0020B.log",  # 1
    "message_2016-6-5_0100B.log",  # 1
    "message_2016-6-5_0140B.log",  # 1
    "message_2016-6-5_0220B.log",  # 1
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_2340B.log.csv
# index_message_2016-6-5_0020B.log.csv
# index_message_2016-6-5_0100B.log.csv
# index_message_2016-6-5_0140B.log.csv
# index_message_2016-6-5_0220B.log.csv
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Phi=5

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-4_2340.log",  # 5
    "message_2016-6-5_0020.log",  # 5
    "message_2016-6-5_0100.log",  # 5
    "message_2016-6-5_0140.log",  # 5
    "message_2016-6-5_0220.log",  # 5
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_2340.log.csv
# index_message_2016-6-5_0020.log.csv
# index_message_2016-6-5_0100.log.csv
# index_message_2016-6-5_0140.log.csv
# index_message_2016-6-5_0220.log.csv

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Phi=10

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-5_0300.log",  # 10
    "message_2016-6-5_0340.log",  # 10
    "message_2016-6-5_0420.log",  # 10
    "message_2016-6-5_0500.log",  # 10
    "message_2016-6-5_0540.log",  # 10
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-5_0300.log.csv
# index_message_2016-6-5_0340.log.csv
# index_message_2016-6-5_0420.log.csv
# index_message_2016-6-5_0500.log.csv
# index_message_2016-6-5_0540.log.csv

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Phi=20

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-5_0300B.log",  # 20
    "message_2016-6-5_0340B.log",  # 20
    "message_2016-6-5_0420B.log",  # 20
    "message_2016-6-5_0500B.log",  # 20
    "message_2016-6-5_0540B.log",  # 20
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-5_0300B.log.csv
# index_message_2016-6-5_0340B.log.csv
# index_message_2016-6-5_0420B.log.csv
# index_message_2016-6-5_0500B.log.csv
# index_message_2016-6-5_0540B.log.csv

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Phi=50

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-5_0620.log",  # 50
    "message_2016-6-5_0700.log",  # 50
    "message_2016-6-5_0740.log",  # 50
    "message_2016-6-5_0820.log",  # 50
    "message_2016-6-5_0900.log",  # 50
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-5_0620.log.csv
# index_message_2016-6-5_0700.log.csv
# index_message_2016-6-5_0740.log.csv
# index_message_2016-6-5_0820.log.csv
# index_message_2016-6-5_0900.log.csv

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Phi=100

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-5_0620B.log",  # 100
    "message_2016-6-5_0700B.log",  # 100
    "message_2016-6-5_0740B.log",  # 100
    "message_2016-6-5_0820B.log",  # 100
    "message_2016-6-5_0900B.log",  # 100
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-5_0620B.log.csv
# index_message_2016-6-5_0700B.log.csv
# index_message_2016-6-5_0740B.log.csv
# index_message_2016-6-5_0820B.log.csv
# index_message_2016-6-5_0900B.log.csv

# %%
ts_name = file_list
styles = ['-', '-', '-','-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.6, -0.4),
           )

# %% [markdown]
# # Compare phi

# %%
file_list = ['index_'+file+'.csv' for file in [
    "message_2016-6-4_2340B.log",  # 1
    "message_2016-6-5_1504_QNN_Phi2.log",  # 2
    "message_2016-6-5_1604_QNN_Phi3.log",  # 3
    "message_2016-6-5_1704_QNN_Phi4.log",  # 4
    "message_2016-6-4_2340.log",  # 5
#     "message_2016-6-5_0300.log",  # 10
#     "message_2016-6-5_0300B.log",  # 20
#     "message_2016-6-5_0620.log",  # 50
#     "message_2016-6-5_0620B.log",  # 100
]]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_2340B.log.csv
# index_message_2016-6-5_1504_QNN_Phi2.log.csv
# index_message_2016-6-5_1604_QNN_Phi3.log.csv
# index_message_2016-6-5_1704_QNN_Phi4.log.csv
# index_message_2016-6-4_2340.log.csv

# %%
ts_name = ['1', '2', '3', '4', '5', '10', '20']
styles = ['-', '-', '-','-', '-', '-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
#     ts.index = pd.Index(step)
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, 
#             logx=True,
            style=styles[i], 
            ylim=(-0.8, -0.4),
           )
