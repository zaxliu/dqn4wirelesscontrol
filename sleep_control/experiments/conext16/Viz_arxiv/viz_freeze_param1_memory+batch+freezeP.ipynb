# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Memory size

# %%
file_list = ["index_message_2016-6-4_0300B.log.csv",
             "index_message_2016-6-4_0300.log.csv",
             "index_message_2016-6-4_0200.log.csv",
             "index_message_2016-6-4_0200B.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_0300B.log.csv
# index_message_2016-6-4_0300.log.csv
# index_message_2016-6-4_0200.log.csv
# index_message_2016-6-4_0200B.log.csv
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ts_name = ['100','200', '300', '400']
styles = ['-', '-', '-','-']

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-1, -0.4), style=styles[i])

# %% [markdown]
# # freeze period

# %%
file_list = [
    "index_message_2016-6-4_1631.log.csv",  # 1
    "index_message_2016-6-4_1633.log.csv",  # 5
    "index_message_2016-6-4_0500.log.csv",  # 10
    "index_message_2016-6-4_0400.log.csv",  # 25
    "index_message_2016-6-4_0200B.log.csv", # 50
    "index_message_2016-6-4_0400B.log.csv", # 100
]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_1631.log.csv
# index_message_2016-6-4_1633.log.csv
# index_message_2016-6-4_0500.log.csv
# index_message_2016-6-4_0400.log.csv
# index_message_2016-6-4_0200B.log.csv
# index_message_2016-6-4_0400B.log.csv
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ts_name = ['1','5', '10', '25','50', '100']
styles = ['-']*6

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-0.6, -0.4), style=styles[i])

# %% [markdown]
# # batch size

# %%
file_list = ["index_message_2016-6-4_0300.log.csv",
             "index_message_2016-6-4_0600.log.csv",
             "index_message_2016-6-4_0600B.log.csv",
             "index_message_2016-6-4_1531.log.csv",
             "index_message_2016-6-4_1533.log.csv",
             ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-4_0300.log.csv
# index_message_2016-6-4_0600.log.csv
# index_message_2016-6-4_0600B.log.csv
# index_message_2016-6-4_1531.log.csv
# index_message_2016-6-4_1533.log.csv

# %%
ts_name = ['100','50', '25', '150', '200']
styles = ['-']*5

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-0.6, -0.4), style=styles[i])
