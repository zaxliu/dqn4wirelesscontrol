# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Phi=1

# %%
file_list = ["index_message_2016-6-3_1640.log.csv",
             "index_message_2016-6-3_1800.log.csv",
             "index_message_2016-6-3_1840.log.csv",
             "index_message_2016-6-2_1914.log.csv",
             "index_message_2016-6-2_1954.log.csv",
             "index_message_2016-6-2_2254.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-3_1640.log.csv
# index_message_2016-6-3_1800.log.csv
# index_message_2016-6-3_1840.log.csv
# index_message_2016-6-2_1914.log.csv
# index_message_2016-6-2_1954.log.csv
# index_message_2016-6-2_2254.log.csv

# %%
ts_name = ['1','2', '3', 'C1', 'C2', 'C3']
styles = ['-', '-', '-','-.', '-.', '-.']

# %% [markdown]
# De-coupled loss fcn is better, ~0.05

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-0.6, -0.4), style=styles[i])

# %% [markdown]
# # Phi=5

# %%
file_list = ["index_message_2016-6-3_1600.log.csv",
             "index_message_2016-6-3_1920.log.csv",
             "index_message_2016-6-3_2000.log.csv",
             "index_message_2016-6-3_0100.log.csv",
             "index_message_2016-6-3_0140.log.csv",
             "index_message_2016-6-3_0220.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-3_1600.log.csv
# index_message_2016-6-3_1920.log.csv
# index_message_2016-6-3_2000.log.csv
# index_message_2016-6-3_0100.log.csv
# index_message_2016-6-3_0140.log.csv
# index_message_2016-6-3_0220.log.csv

# %%
ts_name = ['1','2', '3', 'C1', 'C2', 'C3']
styles = ['-', '-', '-', '-.', '-.', '-.']

# %% [markdown]
# Couples loss fcn is better, 0.01

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-0.6, -0.4), style=styles[i])

# %% [markdown]
# # Phi=10

# %%
file_list = ["index_message_2016-6-3_1413.log.csv",
             "index_message_2016-6-3_2030.log.csv",
             "index_message_2016-6-3_2034.log.csv",
             "index_message_2016-6-2_1535.log.csv",
             "index_message_2016-6-2_1736.log.csv",
             "index_message_2016-6-2_2340.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-3_1413.log.csv
# index_message_2016-6-3_2030.log.csv
# index_message_2016-6-3_2034.log.csv
# index_message_2016-6-2_1535.log.csv
# index_message_2016-6-2_1736.log.csv
# index_message_2016-6-2_2340.log.csv

# %%
ts_name = ['1','2', '3', 'C1', 'C2', 'C3']
styles = ['-', '-', '-', '-.', '-.', '-.']

# %% [markdown]
# Couples loss fcn is better, 0.01

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax, ylim=(-0.6, -0.4), style=styles[i])

# %% [markdown]
# # Phi=50

# %%
file_list = ["index_message_2016-6-3_1511.log.csv",
             "index_message_2016-6-3_2100.log.csv",
             "index_message_2016-6-3_2140.log.csv",
             "index_message_2016-6-3_0300.log.csv",
            "index_message_2016-6-3_0340.log.csv",
             "index_message_2016-6-3_0420.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-3_1511.log.csv
# index_message_2016-6-3_2100.log.csv
# index_message_2016-6-3_2140.log.csv
# index_message_2016-6-3_0300.log.csv
# index_message_2016-6-3_0340.log.csv
# index_message_2016-6-3_0420.log.csv

# %%
ts_name = ['1','2', '3', 'C1', 'C2', 'C3']
styles = ['-', '-', '-', '-.', '-.', '-.']

# %% [markdown]
# Couples loss fcn is better, 0.02

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax,
            ylim=(-0.8, -0.4),
            style=styles[i])

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-26 00:00:00")
plt.figure(1)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    df['total_reward'][:].resample('5Min').plot(figsize=(20, 10), legend=True, ax=ax, style=styles[i], ylim=(-5, 5))

# %% [markdown]
# # Phi=100

# %%
file_list = ["index_message_2016-6-3_2110.log.csv",
             "index_message_2016-6-3_2150.log.csv",
             "index_message_2016-6-3_2220B.log.csv",
             "index_message_2016-6-3_2250.log.csv",
            "index_message_2016-6-2_1040.log.csv",
            ]
df_list = [pd.read_csv(f, delimiter=';', index_col=0) for f in file_list]
for i, df in enumerate(df_list):
    df.loc[:, 'start_ts'] = df['start_ts'].apply(lambda x: pd.to_datetime(x))
    df.set_index('start_ts', inplace=True)
    df['total_reward'] = df['tr_reward'] - df['op_cost']
    print file_list[i]
# Out:
# index_message_2016-6-3_2110.log.csv
# index_message_2016-6-3_2150.log.csv
# index_message_2016-6-3_2220B.log.csv
# index_message_2016-6-3_2250.log.csv
# index_message_2016-6-2_1040.log.csv

# %%
ts_name = ['1','2', '3','4', 'C1', 'C2', 'C3']
styles = ['-', '-', '-', '-','-.', '-.', '-.']

# %% [markdown]
# Couples loss fcn is better, 0.02

# %%
start = pd.to_datetime("2014-09-27 0:00:00")
end = pd.to_datetime("2014-09-28 00:00:00")
delta = pd.Timedelta('2 seconds')
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    step = (df.index-df.index[0])/delta+1
    ts = df['total_reward'].cumsum()/step
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax,
            ylim=(-1, -0),
            style=styles[i])

# %%
plt.figure(2)
ax = plt.subplot(111)
for i, df in enumerate(df_list):
    ts = df['total_reward'].resample('5Min')
    ts.name = ts_name[i]
    ts.plot(figsize=(20, 10), legend=True, ax=ax,
            #ylim=(-1, -0),
            style=styles[i])
